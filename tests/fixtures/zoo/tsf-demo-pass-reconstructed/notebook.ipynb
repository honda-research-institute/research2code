# %% [markdown]
# # Reconstruction fixture — time-series forecasting demo, adjacent-good shape
#
# The PASS twin of tsf-demo-nan-metrics-reconstructed: finite held-out
# metrics, naive baselines printed beside the model, and the deterministic
# `Demo verdict:` line the TE-TSF notebook layout specifies.

# %% [markdown]
# ## 0. Install dependencies (first run only)

# %%
# %pip install -r requirements.txt

# %% [markdown]
# ## 1. Setup

# %%
# %matplotlib inline
import numpy as np
SEED = 42

# %% [markdown]
# ## 2. Parameters

# %%
cfg = {'context_length': 10, 'forecast_horizon': 4}

# %% [markdown]
# ## 3. The setup pieces

# %%
tables = load_data()
# Out:
# Aggregated data: 30 articles x 156 weeks

# %% [markdown]
# ## 4. The GraphDeepAR method

# %%
explain()

# %% [markdown]
# ## 5. Training and forecasting end-to-end

# %%
model, losses = train_model(...)
# Out:
# epoch 1/5: loss 3.217
# epoch 5/5: loss 0.992

# %%
evaluate()
# Out:
# Evaluation on 30 articles, 4 forecast steps (held-out window 148-151, live extent 151):
#   RMSE:  12.31
#   MAE:   8.05
#   WMAPE: 0.42
# Baselines — predict-zero RMSE: 53.75 | repeat-last RMSE: 12.95
# Demo verdict: PASS — finite metrics on a window with signal; beats predict-zero (12.31 < 53.75)

# %% [markdown]
# ## 6. Use your own data
