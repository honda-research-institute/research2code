# %% [markdown]
# # Reconstructed motion-planning demo (scenario-fidelity fixture)

# %% [markdown]
# ## 0. Install dependencies (first run only)

# %%
# %pip install -q numpy

# %% [markdown]
# ## 1. Setup

# %%
import math
import random

random.seed(7)

# %% [markdown]
# ## 2. Parameters

# %%
params = {"d_safe": 0.5, "horizon": 12, "dt": 0.1}

# %% [markdown]
# ## 3. The setup pieces

# %%
# Reconstructed from the recorded circles-vs-polygon validity bug:
# the paper states circular obstacles, the demo builds polygons.
obstacles = [
    {"type": "polygon", "vertices": [[1.0, 1.0], [2.0, 1.0], [1.5, 2.0]]},
    {"type": "polygon",
     "vertices": [[3.0, 0.5], [4.0, 0.5], [4.0, 1.5], [3.0, 1.5]]},
]

class Environment:
    """Reconstruction of the paradigm-template Environment surface."""

    def __init__(self, name, obstacles):
        self.name = name
        self.obstacles = list(obstacles)


env = Environment("reconstructed-scene", obstacles)
start = [0.0, 0.0, 0.0]
goal = [5.0, 5.0]

# %% [markdown]
# ## 4. The reconstructed method ⭐

# %%
raise RuntimeError(
    "section 4 must never execute in the setup slice")

# %% [markdown]
# ## 5. Running the planner end-to-end

# %%
raise RuntimeError(
    "section 5 (demo) must never execute in the setup slice")
