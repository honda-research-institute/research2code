# %% [markdown]
# # Reconstruction fixture — time-series forecasting demo, the loop2 NaN shape
#
# Built 2026-08-06 from the executed-output lines quoted in
# `audit/reports/2026-08-06-pdfgnn-loop2-quality-review.md` (the run's own
# notebook printed RMSE/MAE/WMAPE = nan over a held-out window with no
# ground truth). Only the headline-section outputs are load-bearing.

# %% [markdown]
# ## 0. Install dependencies (first run only)

# %%
# %pip install -r requirements.txt

# %% [markdown]
# ## 1. Setup

# %%
# %matplotlib inline
import numpy as np
SEED = 42

# %% [markdown]
# ## 2. Parameters

# %%
cfg = {'context_length': 10, 'forecast_horizon': 4}

# %% [markdown]
# ## 3. The setup pieces

# %%
tables = load_data()
# Out:
# Aggregated data: 30 articles x 156 weeks

# %% [markdown]
# ## 4. The GraphDeepAR method

# %%
explain()

# %% [markdown]
# ## 5. Training and forecasting end-to-end

# %%
model = train_model(...)
# Out:
# Training complete.

# %%
evaluate()
# Out:
# Evaluation on 30 articles, 4 forecast steps:
#   RMSE:  nan
#   MAE:   nan
#   WMAPE: nan

# %% [markdown]
# ## 6. Use your own data
